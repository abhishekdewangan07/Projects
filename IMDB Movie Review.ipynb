# %%
#Import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import naive_bayes
from sklearn.metrics import roc_auc_score

# %%
#Load the dataset
IMDB_data = pd.read_csv("IMDB Dataset.csv")
IMDB_data.head(10)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# 5  Probably my all-time favorite movie, a story o...  positive
# 6  I sure would like to see a resurrection of a u...  positive
# 7  This show was an amazing, fresh & innovative i...  negative
# 8  Encouraged by the positive comments about this...  negative
# 9  If you like original gut wrenching laughter yo...  positive

# %% [markdown]
# #### Data Analysis

# %%
#Check for null data
IMDB_data.isnull().any()
# Out:
# review       False
# sentiment    False
# dtype: bool

# %%
np.unique(IMDB_data['sentiment'],return_counts=True)
# Out:
# (array(['negative', 'positive'], dtype=object),
#  array([25000, 25000], dtype=int64))

# %% [markdown]
# #### Data Preprocessing

# %%
vectorizer = TfidfVectorizer(strip_accents='ascii',lowercase=True,stop_words = stopwords.words('english'))

# %%
X = vectorizer.fit_transform(IMDB_data['review'])

# %%
print(np.array(X))
# Out:
#   (0, 81735)	0.04692247277576888
#   (0, 22625)	0.07419429343840393
#   (0, 91779)	0.057538817730462544
#   (0, 90143)	0.06205586219391211
#   (0, 96993)	0.05233732786853565
#   (0, 94123)	0.07138248027809192
#   (0, 18632)	0.07312701519388139
#   (0, 8982)	0.04515458812637841
#   (0, 56534)	0.03699927796746985
#   (0, 31346)	0.04818419434808489
#   (0, 82436)	0.06481667768152764
#   (0, 86423)	0.055018425747524996
#   (0, 50949)	0.04874153884178886
#   (0, 10378)	0.10069636079727004
#   (0, 93290)	0.04970717793322766
#   (0, 17537)	0.05179036899122877
#   (0, 58076)	0.04982556982178736
#   (0, 55518)	0.08431980729476911
#   (0, 98647)	0.025150235896227887
#   (0, 37010)	0.052903606204067866
#   (0, 64469)	0.04986530831894351
#   (0, 49632)	0.04803063502804875
#   (0, 45652)	0.1700402454457881
#   (0, 62186)	0.10397926209555218
#   (0, 83694)	0.07002382721974176
#   :	:
#   (49999, 43277)	0.08262134450972523
#   (49999, 32082)	0.09642527783262565
#   (49999, 85442)	0.09818782505482437
#   (49999, 100256)	0.08952743325416027
#   (49999, 60248)	0.1991532623804596
#   (49999, 38090)	0.05146243663491215
#   (49999, 9768)	0.06914237433096918
#   (49999, 4930)	0.07702727758309143
#   (49999, 98226)	0.06598811084552848
#   (49999, 60212)	0.27323236705794146
#   (49999, 30774)	0.10963898244864372
#   (49999, 16057)	0.06760815056968077
#   (49999, 68882)	0.0683587638681656
#   (49999, 98351)	0.06387643489552067
#   (49999, 100258)	0.18090379201360646
#   (49999, 79715)	0.11106023780921317
#   (49999, 98647)	0.05765112144555645
#   (49999, 78511)	0.07188100326992455
#   (49999, 100278)	0.05567038725686491
#   (49999, 32200)	0.1717250286767452
#   (49999, 41959)	0.09431672995491586
#   (49999, 78732)	0.07446836625057475
#   (49999, 12068)	0.08045120337896458
#   (49999, 98242)	0.07540703531784014
#   (49999, 64112)	0.040916300907300786

# %%
X.shape
# Out:
# (50000, 101865)

# %%
IMDB_data['sentiment'].unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
y = IMDB_data['sentiment'].replace(('positive','negative'),(1,0))

# %%
np.unique(y,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([25000, 25000], dtype=int64))

# %%
vectorizer.vocabulary_
# Out:
# {'one': 64112,
#  'reviewers': 75520,
#  'mentioned': 57555,
#  'watching': 98242,
#  'oz': 65461,
#  'episode': 30092,
#  'hooked': 42857,
#  'right': 75923,
#  'exactly': 30957,
#  'happened': 40434,
#  'br': 12068,
#  'first': 33530,
#  'thing': 90394,
#  'struck': 86608,
#  'brutality': 12998,
#  'unflinching': 94646,
#  'scenes': 78732,
#  'violence': 97171,
#  'set': 80305,
#  'word': 100126,
#  'go': 37791,
#  'trust': 92981,
#  'show': 81428,
#  'faint': 31905,
#  'hearted': 41159,
#  'timid': 90985,
#  'pulls': 71605,
#  'punches': 71652,
#  'regards': 74110,
#  'drugs': 27436,
#  'sex': 80403,
#  'hardcore': 40496,
#  'classic': 17541,
#  'use': 95846,
#  'called': 14109,
#  'nickname': 62205,
#  'given': 37474,
#  'oswald': 64752,
#  'maximum': 56527,
#  'security': 79676,
#  'state': 85560,
#  'penitentary': 67066,
#  'focuses': 34255,
#  'mainly': 54973,
#  'emerald': 29235,
#  'city': 17388,
#  'experimental': 31354,
#  'section': 79655,
#  'prison': 70619,
#  'cells': 15591,
#  'glass': 37549,
#  'fronts': 35441,
#  'face': 31782,
#  'inwards': 46580,
#  'privacy': 70635,
#  'high': 41959,
#  'agenda': 3041,
#  'em': 29118,
#  'home': 42638,
#  'many': 55613,
#  'aryans': 6174,
#  'muslims': 60796,
#  'gangstas': 36212,
#  'latinos': 51581,
#  'christians': 16984,
#  'italians': 46927,
#  'irish': 46662,
#  'scuffles': 79416,
#  'death': 22971,
#  'stares': 85469,
#  'dodgy': 26378,
#  'dealings': 22941,
#  'shady': 80527,
#  'agreements': 3146,
#  'never': 62001,
#  'far': 32200,
#  'away': 7242,
#  'would': 100278,
#  'say': 78511,
#  'main': 54959,
#  'appeal': 5361,
#  'due': 27598,
#  'fact': 31828,
#  'goes': 37914,
#  'shows': 81463,
#  'dare': 22601,
#  'forget': 34592,
#  'pretty': 70461,
#  'pictures': 68118,
#  'painted': 65667,
#  'mainstream': 54983,
#  'audiences': 6845,
#  'charm': 16134,
#  'romance': 76563,
#  'mess': 57752,
#  'around': 5963,
#  'ever': 30800,
#  'saw': 78480,
#  'nasty': 61375,
#  'surreal': 87835,
#  'ready': 73310,
#  'watched': 98235,
#  'developed': 24620,
#  'taste': 89182,
#  'got': 38304,
#  'accustomed': 2185,
#  'levels': 52440,
#  'graphic': 38611,
#  'injustice': 45631,
#  'crooked': 21466,
#  'guards': 39318,
#  'sold': 83694,
#  'nickel': 62186,
#  'inmates': 45652,
#  'kill': 49632,
#  'order': 64469,
#  'get': 37010,
#  'well': 98647,
#  'mannered': 55518,
#  'middle': 58076,
#  'class': 17537,
#  'turned': 93290,
#  'bitches': 10378,
#  'lack': 50949,
#  'street': 86423,
#  'skills': 82436,
#  'experience': 31346,
#  'may': 56534,
#  'become': 8982,
#  'comfortable': 18632,
#  'uncomfortable': 94123,
#  'viewing': 96993,
#  'thats': 90143,
#  'touch': 91779,
#  'darker': 22625,
#  'side': 81735,
#  'wonderful': 99978,
#  'little': 53148,
#  'production': 70789,
#  'filming': 33263,
#  'technique': 89447,
#  'unassuming': 93965,
#  'old': 63968,
#  'time': 90935,
#  'bbc': 8754,
#  'fashion': 32350,
#  'gives': 37477,
#  'comforting': 18635,
#  'sometimes': 83836,
#  'discomforting': 25527,
#  'sense': 80022,
#  'realism': 73340,
#  'entire': 29918,
#  'piece': 68139,
#  'actors': 2378,
#  'extremely': 31627,
#  'chosen': 16927,
#  'michael': 57982,
#  'sheen': 80864,
#  'polari': 69148,
#  'voices': 97457,
#  'pat': 66462,
#  'truly': 92952,
#  'see': 79715,
#  'seamless': 79513,
#  'editing': 28422,
#  'guided': 39399,
#  'references': 73981,
#  'williams': 99442,
#  'diary': 24881,
#  'entries': 29968,
#  'worth': 100258,
#  'terrificly': 89913,
#  'written': 100422,
#  'performed': 67257,
#  'masterful': 56217,
#  'great': 38746,
#  'master': 56209,
#  'comedy': 18607,
#  'life': 52658,
#  'really': 73365,
#  'comes': 18620,
#  'things': 90403,
#  'fantasy': 32182,
#  'guard': 39306,
#  'rather': 73064,
#  'traditional': 91997,
#  'dream': 27200,
#  'techniques': 89448,
#  'remains': 74507,
#  'solid': 83730,
#  'disappears': 25421,
#  'plays': 68763,
#  'knowledge': 50157,
#  'senses': 80028,
#  'particularly': 66315,
#  'concerning': 19142,
#  'orton': 64668,
#  'halliwell': 40102,
#  'sets': 80324,
#  'flat': 33779,
#  'murals': 60672,
#  'decorating': 23222,
#  'every': 30831,
#  'surface': 87764,
#  'terribly': 89906,
#  'done': 26605,
#  'thought': 90536,
#  'way': 98351,
#  'spend': 84536,
#  'hot': 43140,
#  'summer': 87343,
#  'weekend': 98510,
#  'sitting': 82271,
#  'air': 3283,
#  'conditioned': 19245,
#  'theater': 90170,
#  'light': 52707,
#  'plot': 68882,
#  'simplistic': 82042,
#  'dialogue': 24836,
#  'witty': 99832,
#  'characters': 16057,
#  'likable': 52753,
#  'even': 30774,
#  'bread': 12319,
#  'suspected': 87914,
#  'serial': 80216,
#  'killer': 49643,
#  'disappointed': 25424,
#  'realize': 73354,
#  'match': 56278,
#  'point': 69080,
#  'risk': 76091,
#  'addiction': 2473,
#  'proof': 71001,
#  'woody': 100057,
#  'allen': 3765,
#  'still': 85961,
#  'fully': 35623,
#  'control': 19969,
#  'style': 86796,
#  'us': 95830,
#  'grown': 39187,
#  'love': 53859,
#  'laughed': 51634,
#  'comedies': 18604,
#  'years': 100891,
#  'decade': 23072,
#  'impressed': 44690,
#  'scarlet': 78660,
#  'johanson': 48016,
#  'managed': 55296,
#  'tone': 91464,
#  'sexy': 80449,
#  'image': 44334,
#  'jumped': 48407,
#  'average': 7136,
#  'spirited': 84685,
#  'young': 101143,
#  'woman': 99948,
#  'crown': 21555,
#  'jewel': 47771,
#  'career': 14709,
#  'wittier': 99825,
#  'devil': 24662,
#  'wears': 98427,
#  'prada': 69956,
#  'interesting': 46122,
#  'superman': 87568,
#  'friends': 35309,
#  'basically': 8495,
#  'family': 32069,
#  'boy': 12024,
#  'jake': 47233,
#  'thinks': 90413,
#  'zombie': 101722,
#  'closet': 17884,
#  'parents': 66155,
#  'fighting': 33147,
#  'movie': 60212,
#  'slower': 82929,
#  'soap': 83481,
#  'opera': 64278,
#  'suddenly': 87142,
#  'decides': 23144,
#  'rambo': 72775,
#  'ok': 63907,
#  'going': 37942,
#  'make': 55045,
#  'film': 33219,
#  'must': 60816,
#  'decide': 23139,
#  'thriller': 90606,
#  'drama': 27105,
#  'watchable': 98229,
#  'divorcing': 26202,
#  'arguing': 5775,
#  'like': 52755,
#  'real': 73327,
#  'totally': 91747,
#  'ruins': 77188,
#  'expected': 31311,
#  'boogeyman': 11541,
#  'similar': 81982,
#  'instead': 45886,
#  'meaningless': 57013,
#  'spots': 84911,
#  '10': 57,
#  'playing': 68749,
#  'descent': 24278,
#  'dialogs': 24835,
#  'shots': 81393,
#  'ignore': 44188,
#  'petter': 67636,
#  'mattei': 56400,
#  'money': 59421,
#  'visually': 97315,
#  'stunning': 86732,
#  'watch': 98226,
#  'mr': 60312,
#  'offers': 63778,
#  'vivid': 97377,
#  'portrait': 69625,
#  'human': 43478,
#  'relations': 74384,
#  'seems': 79750,
#  'telling': 89639,
#  'power': 69891,
#  'success': 87077,
#  'people': 67132,
#  'different': 25019,
#  'situations': 82279,
#  'encounter': 29494,
#  'variation': 96317,
#  'arthur': 6092,
#  'schnitzler': 78930,
#  'play': 68722,
#  'theme': 90224,
#  'director': 25343,
#  'transfers': 92156,
#  'action': 2345,
#  'present': 70345,
#  'new': 62021,
#  'york': 101098,
#  'meet': 57210,
#  'connect': 19482,
#  'connected': 19483,
#  'another': 4930,
#  'next': 62112,
#  'person': 67433,
#  'know': 50148,
#  'previous': 70490,
#  'contact': 19769,
#  'stylishly': 86807,
#  'sophisticated': 83971,
#  'luxurious': 54318,
#  'look': 53592,
#  'taken': 88770,
#  'live': 53167,
#  'world': 100193,
#  'habitat': 39825,
#  'gets': 37022,
#  'souls': 84108,
#  'picture': 68115,
#  'stages': 85257,
#  'loneliness': 53523,
#  'inhabits': 45555,
#  'big': 10054,
#  'best': 9768,
#  'place': 68558,
#  'find': 33359,
#  'sincere': 82079,
#  'fulfillment': 35601,
#  'discerns': 25490,
#  'case': 15050,
#  'acting': 2340,
#  'good': 38090,
#  'direction': 25333,
#  'steve': 85884,
#  'buscemi': 13598,
#  'rosario': 76745,
#  'dawson': 22829,
#  'carol': 14866,
#  'kane': 48759,
#  'imperioli': 44561,
#  'adrian': 2700,
#  'grenier': 38862,
#  'rest': 75208,
#  'talented': 88812,
#  'cast': 15128,
#  'come': 18592,
#  'alive': 3724,
#  'wish': 99714,
#  'luck': 54037,
#  'await': 7217,
#  'anxiously': 5161,
#  'work': 100151,
#  'probably': 70687,
#  'favorite': 32494,
#  'story': 86219,
#  'selflessness': 79878,
#  'sacrifice': 77556,
#  'dedication': 23263,
#  'noble': 62546,
#  'cause': 15384,
#  'preachy': 70040,
#  'boring': 11746,
#  'despite': 24416,
#  'seen': 79752,
#  '15': 237,
#  'times': 90965,
#  'last': 51522,
#  '25': 781,
#  'paul': 66618,
#  'lukas': 54116,
#  'performance': 67251,
#  'brings': 12628,
#  'tears': 89409,
#  'eyes': 31696,
#  'bette': 9827,
#  'davis': 22803,
#  'sympathetic': 88412,
#  'roles': 76517,
#  'delight': 23673,
#  'kids': 49569,
#  'grandma': 38561,
#  'says': 78529,
#  'dressed': 27272,
#  'midgets': 58097,
#  'children': 16651,
#  'makes': 55055,
#  'fun': 35647,
#  'mother': 60042,
#  'slow': 82924,
#  'awakening': 7225,
#  'happening': 40436,
#  'roof': 76659,
#  'believable': 9310,
#  'startling': 85536,
#  'dozen': 27029,
#  'thumbs': 90706,
#  'sure': 87751,
#  'resurrection': 75282,
#  'dated': 22735,
#  'seahunt': 79497,
#  'series': 80223,
#  'tech': 89427,
#  'today': 91263,
#  'bring': 12623,
#  'back': 7507,
#  'kid': 49531,
#  'excitement': 31064,
#  'grew': 38880,
#  'black': 10457,
#  'white': 99081,
#  'tv': 93384,
#  'gunsmoke': 39600,
#  'hero': 41705,
#  'week': 98507,
#  'vote': 97573,
#  'comeback': 18593,
#  'sea': 79470,
#  'hunt': 43634,
#  'need': 61687,
#  'change': 15952,
#  'pace': 65515,
#  'water': 98256,
#  'adventure': 2751,
#  'oh': 63853,
#  'thank': 90112,
#  'outlet': 64922,
#  'view': 96985,
#  'viewpoints': 96997,
#  'movies': 60248,
#  'ole': 63992,
#  'believe': 9312,
#  'wanna': 98022,
#  'nice': 62157,
#  'read': 73288,
#  'plus': 68971,
#  'points': 69101,
#  'rhymes': 75713,
#  'lines': 52926,
#  'let': 52374,
#  'submit': 86928,
#  'leave': 51929,
#  'doubt': 26896,
#  'quit': 72320,
#  'lets': 52395,
#  'amazing': 4138,
#  'fresh': 35234,
#  'innovative': 45698,
#  'idea': 44028,
#  '70': 1255,
#  'aired': 3297,
#  'brilliant': 12603,
#  'dropped': 27388,
#  '1990': 573,
#  'funny': 35720,
#  'anymore': 5174,
#  'continued': 19877,
#  'decline': 23188,
#  'complete': 18940,
#  'waste': 98206,
#  'disgraceful': 25663,
#  'fallen': 31996,
#  'writing': 100419,
#  'painfully': 65655,
#  'bad': 7604,
#  'performances': 67253,
#  'almost': 3893,
#  'mildly': 58250,
#  'entertaining': 29885,
#  'respite': 75175,
#  'guest': 39368,
#  'hosts': 43139,
#  'hard': 40486,
#  'creator': 21132,
#  'hand': 40256,
#  'selected': 79857,
#  'original': 64571,
#  'also': 3962,
#  'chose': 16926,
#  'band': 8009,
#  'hacks': 39862,
#  'followed': 34337,
#  'recognize': 73634,
#  'brilliance': 12601,
#  'fit': 33592,
#  'replace': 74824,
#  'mediocrity': 57153,
#  'felt': 32761,
#  'give': 37470,
#  'stars': 85519,
#  'respect': 75157,
#  'made': 54686,
#  'huge': 43420,
#  'awful': 7260,
#  'encouraged': 29501,
#  'positive': 69683,
#  'comments': 18720,
#  'looking': 53600,
#  'forward': 34748,
#  'mistake': 58922,
#  '950': 1414,
#  'films': 33289,
#  'worst': 100256,
#  'pacing': 65544,
#  'storyline': 86231,
#  'soundtrack': 84138,
#  'song': 83889,
#  'lame': 51161,
#  'country': 20703,
#  'tune': 93193,
#  'played': 68732,
#  'less': 52355,
#  'four': 34816,
#  'looks': 53605,
#  'cheap': 16270,
#  'extreme': 31625,
#  'rarely': 72993,
#  'happy': 40451,
#  'end': 29527,
#  'credits': 21157,
#  'prevents': 70483,
#  'giving': 37479,
#  'score': 79157,
#  'harvey': 40729,
#  'keitel': 49210,
#  'least': 51910,
#  'making': 55065,
#  'bit': 10374,
#  'effort': 28569,
#  'obsessives': 63517,
#  'gut': 39660,
#  'wrenching': 100361,
#  'laughter': 51645,
#  'hell': 41424,
#  'mom': 59357,
#  'liked': 52760,
#  'camp': 14254,
#  'phil': 67799,
#  'alien': 3679,
#  'quirky': 72313,
#  'humour': 43565,
#  'based': 8460,
#  'oddness': 63685,
#  'everything': 30845,
#  'actual': 2386,
#  'punchlines': 71657,
#  'odd': 63675,
#  'progressed': 70884,
#  'jokes': 48070,
#  'low': 53908,
#  'budget': 13143,
#  'problem': 70705,
#  'eventually': 30795,
#  'lost': 53750,
#  'interest': 46118,
#  'imagine': 44352,
#  'stoner': 86129,
#  'currently': 21954,
#  'partaking': 66279,
#  'something': 83829,
#  'better': 9828,
#  'try': 93002,
#  'brother': 12863,
#  'planet': 68622,
#  '12': 152,
#  'came': 14194,
#  'recall': 73516,
#  'scariest': 78652,
#  'scene': 78725,
#  'bird': 10291,
#  'eating': 28218,
#  'men': 57452,
#  'dangling': 22516,
#  'helplessly': 41496,
#  'parachutes': 66014,
#  'horror': 43037,
#  'cheesy': 16382,
#  'saturday': 78371,
#  'afternoons': 2998,
#  'tired': 91093,
#  'formula': 34660,
#  'monster': 59554,
#  'type': 93553,
#  'usually': 95886,
#  'included': 44929,
#  'beautiful': 8923,
#  'might': 58155,
#  'daughter': 22757,
#  'professor': 70821,
#  'resolution': 75124,
#  'died': 24980,
#  'care': 14702,
#  'much': 60369,
#  'romantic': 76581,
#  'angle': 4713,
#  'year': 100879,
#  'predictable': 70138,
#  'plots': 68894,
#  'unintentional': 94870,
#  'humor': 43553,
#  'later': 51553,
#  'psycho': 71401,
#  'loved': 53868,
#  'star': 85442,
#  'janet': 47303,
#  'leigh': 52131,
#  'bumped': 13360,
#  'early': 28123,
#  'sat': 78285,
#  'took': 91508,
#  'notice': 62935,
#  'since': 82078,
#  'screenwriters': 79308,
#  'scary': 78678,
#  'possible': 69715,
#  'worn': 100224,
#  'rules': 77203,
#  'im': 44330,
#  'fan': 32082,
#  'boll': 11347,
#  'enjoyed': 29723,
#  'postal': 69721,
#  'maybe': 56544,
#  'apparently': 5352,
#  'bought': 11889,
#  'rights': 75939,
#  'cry': 21670,
#  'long': 53535,
#  'ago': 3114,
#  'game': 36135,
#  'finsished': 33449,
#  'killing': 49651,
#  'mercs': 57616,
#  'infiltrating': 45409,
#  'secret': 79634,
#  'research': 75021,
#  'labs': 50924,
#  'located': 53340,
#  'tropical': 92837,
#  'island': 46848,
#  'warned': 98109,
#  'schemed': 78803,
#  'together': 91298,
#  'along': 3910,
#  'legion': 52075,
#  'schmucks': 78916,
#  'feeling': 32655,
#  'loneley': 53520,
#  'invites': 46553,
#  'three': 90583,
#  'countrymen': 20706,
#  'players': 68734,
#  'names': 61190,
#  'til': 90893,
#  'schweiger': 79067,
#  'udo': 93676,
#  'kier': 49582,
#  'ralf': 72745,
#  'moeller': 59221,
#  'actually': 2392,
#  'selfs': 79881,
#  'biz': 10415,
#  'tale': 88807,
#  'jack': 47095,
#  'carver': 15024,
#  'yes': 100963,
#  'german': 36943,
#  'hail': 39967,
#  'bratwurst': 12258,
#  'dudes': 27587,
#  'however': 43277,
#  'tils': 90912,
#  'badass': 7610,
#  'complained': 18925,
#  'staying': 85627,
#  'true': 92929,
#  'whole': 99164,
#  'perspective': 67470,
#  'looked': 53595,
#  'kicking': 49526,
#  'beyond': 9896,
#  'demented': 23792,
#  'evil': 30876,
#  'mad': 54651,
#  'scientist': 79090,
#  'dr': 27043,
#  'krieger': 50538,
#  'genetically': 36762,
#  'mutated': 60843,
#  'soldiers': 83703,
#  'gms': 37767,
#  'performing': 67260,
#  'top': 91556,
#  'reminds': 74569,
#  'spoiler': 84796,
#  'vancouver': 96205,
#  'reason': 73417,
#  'palm': 65770,
#  'trees': 92459,
#  'rich': 75757,
#  'lumberjack': 54141,
#  'woods': 100041,
#  'gone': 38067,
#  'started': 85528,
#  'mehehe': 57266,
#  'cannot': 14428,
#  'stay': 85623,
#  'bolls': 11358,
#  'shenanigans': 80948,
#  'delivers': 23706,
#  'meaning': 57007,
#  'suck': 87110,
#  'mentioning': 57556,
#  'imply': 44636,
#  'areas': 5725,
#  'boat': 11105,
#  'cromed': 21442,
#  'albino': 3526,
#  'squad': 85046,
#  'enters': 29875,
#  'laugh': 51631,
#  'reeks': 73935,
#  'scheisse': 78793,
#  'poop': 69425,
#  'simpletons': 82031,
#  'fa': 31738,
#  'take': 88761,
#  'wiff': 99330,
#  'ahead': 3188,
#  'btw': 13049,
#  'annoying': 4900,
#  'sidekick': 81746,
#  'shoot': 81309,
#  'minutes': 58600,
#  'screen': 79288,
#  'shakespeare': 80571,
#  'appreciate': 5467,
#  'trying': 93007,
#  'masses': 56183,
#  'ruin': 77181,
#  'scottish': 79196,
#  'certain': 15725,
#  'rev': 75438,
#  'bowdler': 11967,
#  'hence': 41546,
#  'bowdlerization': 11970,
#  'tried': 92624,
#  'victorian': 96891,
#  'era': 30184,
#  'words': 100139,
#  'improve': 44728,
#  'perfection': 67228,
#  'write': 100407,
#  'ten': 89714,
#  'text': 90049,
#  'english': 29671,
#  'composition': 19009,
#  'forte': 34705,
#  'keep': 49172,
#  'saying': 78520,
#  'cut': 22045,
#  'fantastic': 32172,
#  'prisoners': 70622,
#  'famous': 32080,
#  'george': 36885,
#  'clooney': 17871,
#  'roll': 76522,
#  'man': 55292,
#  'constant': 19687,
#  'sorrow': 84046,
#  'recommand': 73659,
#  'everybody': 30835,
#  'greetings': 38832,
#  'bart': 8415,
#  'kind': 49712,
#  'drawn': 27177,
#  'erotic': 30288,
#  'amateurish': 4118,
#  'unbelievable': 94015,
#  'bits': 10394,
#  'sort': 84051,
#  'school': 78957,
#  'project': 70906,
#  'rosanna': 76742,
#  'arquette': 5974,
#  'thinking': 90412,
#  'stock': 86060,
#  'bizarre': 10417,
#  'supposed': 87693,
#  'midwest': 58134,
#  'town': 91870,
#  'involved': 46568,
#  'lessons': 52364,
#  'learned': 51892,
#  'insights': 45804,
#  'stilted': 85974,
#  'quite': 72321,
#  'ridiculous': 75848,
#  'lots': 53770,
#  'skin': 82451,
#  'intrigues': 46395,
#  'videotaped': 96937,
#  'nonsense': 62727,
#  'bisexual': 10349,
#  'relationship': 74385,
#  'nowhere': 63030,
#  'heterosexual': 41820,
#  'encounters': 29498,
#  'absurd': 1975,
#  'dance': 22459,
#  'stereotyped': 85844,
#  'pass': 66382,
#  'million': 58348,
#  'miles': 58259,
#  'wasted': 98208,
#  'could': 20613,
#  'spent': 84544,
#  'starving': 85546,
#  'aids': 3236,
#  'africa': 2968,
#  'simply': 82044,
#  'remade': 74497,
#  'fails': 31900,
#  'capture': 14616,
#  'flavor': 33825,
#  'terror': 89930,
#  '1963': 528,
#  'title': 91148,
#  'liam': 52524,
#  'neeson': 61709,
#  'excellent': 31021,
#  'always': 4054,
#  'holds': 42500,
#  'exception': 31032,
#  'owen': 65417,
#  'wilson': 99483,
#  'feel': 32651,
#  'character': 16035,
#  'luke': 54118,
#  'major': 55026,
#  'fault': 32461,
#  'version': 96723,
#  'strayed': 86399,
#  'shirley': 81175,
#  'jackson': 47132,
#  'attempts': 6738,
#  'grandiose': 38555,
#  'thrill': 90604,
#  'earlier': 28118,
#  'trade': 91983,
#  'snazzier': 83269,
#  'special': 84408,
#  'effects': 28544,
#  'enjoy': 29719,
#  'friction': 35277,
#  'older': 63973,
#  'horrible': 43016,
#  'continuous': 19884,
#  'minute': 58596,
#  'fight': 33141,
#  'chance': 15923,
#  'development': 24625,
#  'busy': 13673,
#  'running': 77268,
#  'sword': 88308,
#  'emotional': 29330,
#  'attachment': 6716,
#  'except': 31029,
#  'machine': 54561,
#  'wanted': 98032,
#  'destroy': 24459,
#  'blatantly': 10646,
#  'stolen': 86101,
#  'lotr': 53769,
#  'wars': 98149,
#  'matrix': 56382,
#  'examples': 30989,
#  'ghost': 37096,
#  'final': 33332,
#  'yoda': 101035,
#  'obee': 63374,
#  'vader': 96026,
#  'spider': 84587,
#  'beginning': 9164,
#  'frodo': 35399,
#  'attacked': 6720,
#  'return': 75410,
#  'kings': 49766,
#  'elijah': 28950,
#  'wood': 100006,
#  'victim': 96875,
#  'wait': 97831,
#  'hypnotizes': 43873,
#  'stings': 85997,
#  'wraps': 100337,
#  'uh': 93728,
#  'hello': 41454,
#  'vs': 97626,
#  'humans': 43510,
#  'terminator': 89871,
#  'someone': 83814,
#  'tell': 89633,
#  'nazi': 61562,
#  'juvenile': 48525,
#  'line': 52909,
#  'rushed': 77303,
#  'conclusion': 19176,
#  'adult': 2719,
#  'either': 28743,
#  'disappointment': 25427,
#  'save': 78444,
#  'remember': 74547,
#  'cinema': 17237,
#  'dark': 22618,
#  'places': 68567,
#  'nervous': 61899,
#  '74': 1286,
#  '75': 1293,
#  'dad': 22242,
#  'sister': 82239,
#  'newbury': 62031,
#  'berkshire': 9640,
#  'england': 29663,
#  'tigers': 90865,
#  'snow': 83412,
#  'appearance': 5367,
#  'grizzly': 39044,
#  'adams': 2438,
#  'actor': 2375,
#  'dan': 22451,
#  'haggery': 39928,
#  'think': 90406,
#  'shot': 81387,
#  'dies': 24996,
#  'anyone': 5176,
#  'knows': 50167,
#  'dvd': 27951,
#  'etc': 30580,
#  'please': 68797,
#  'fitness': 33596,
#  'club': 17942,
#  'shame': 80630,
#  'nearest': 61605,
#  '20': 617,
#  'hear': 41124,
#  'others': 64772,
#  'stinkers': 86010,
#  'nominated': 62648,
#  'golden': 37971,
#  'globe': 37675,
#  'female': 32764,
#  'renaissance': 74629,
#  'painter': 65668,
#  'mangled': 55405,
#  'recognition': 73630,
#  ...}

# %% [markdown]
# #### Model Building

# %%
#Test Train split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2,test_size = 0.3)

# %%
#naive bayes classifier

model = naive_bayes.MultinomialNB()
model.fit(X_train,y_train)
result = model.predict(X_test)

# %%
result
# Out:
# array([0, 0, 1, ..., 1, 0, 1], dtype=int64)

# %%
# test our model's accuracy
roc_auc_score(y_test,result)
# Out:
# 0.866667944296319

# %%
# how does it work?

movie_reviews_array = np.array(["Batla House is a terrific movie"])

movie_review_vector = vectorizer.transform(movie_reviews_array)


#predicting result
model.predict(movie_review_vector)
# Out:
# array([1], dtype=int64)
